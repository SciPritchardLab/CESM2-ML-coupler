# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/scratch/00993/tg802402/NNrealgeographyonline001/run"
lhs = xr.open_mfdataset(path+"/NNrealgeographyonline001.cam.h2.2004-01-01-*.nc")

# %%
lhs
# Out:
# <xarray.Dataset>
# Dimensions:       (ilev: 27, lat: 96, lev: 26, lon: 144, nbnd: 2, time: 20)
# Coordinates:
#   * lat           (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * lon           (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lev           (lev) float64 3.545 7.389 13.97 23.94 ... 929.6 970.6 992.6
#   * ilev          (ilev) float64 2.194 4.895 9.882 18.05 ... 956.0 985.1 1e+03
#   * time          (time) object 2004-01-01 00:00:00 ... 2004-01-01 09:30:00
# Dimensions without coordinates: nbnd
# Data variables:
#     gw            (time, lat) float64 dask.array<concatenate, shape=(20, 96),...
#     hyam          (time, lev) float64 dask.array<concatenate, shape=(20, 26),...
#     hybm          (time, lev) float64 dask.array<concatenate, shape=(20, 26),...
#     P0            (time) float64 1e+05 1e+05 1e+05 1e+05 ... 1e+05 1e+05 1e+05
#     hyai          (time, ilev) float64 dask.array<concatenate, shape=(20, 27)...
# ...

# %%
thedata= lhs.NN_BP2BC_DT

# %%
bar
# Out:
# <xarray.DataArray 'NN_BP2BC_DT' (time: 20, lev: 26, lat: 96, lon: 144)>
# dask.array<concatenate, shape=(20, 26, 96, 144), dtype=float32, chunksize=(1, 26, 96, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lev      (lev) float64 3.545 7.389 13.97 23.94 ... 867.2 929.6 970.6 992.6
#   * time     (time) object 2004-01-01 00:00:00 ... 2004-01-01 09:30:00
# Attributes:
#     mdims:         1
#     units:         K
#     long_name:     T increment due to NN BP-->BC
#     cell_methods:  time: mean

# %%
thedata_ztmean = thedata.mean(dim=("lon","time"))

# %%
thedata_ztmean
# Out:
# <xarray.DataArray 'NN_BP2BC_DT' (lev: 26, lat: 96)>
# dask.array<mean_agg-aggregate, shape=(26, 96), dtype=float32, chunksize=(26, 96), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 84.32 86.21 88.11 90.0
#   * lev      (lev) float64 3.545 7.389 13.97 23.94 ... 867.2 929.6 970.6 992.6

# %%
aux = thedata_ztmean.values

# %%
plt.image(aux)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-75f564133c29> in <module>
# ----> 1 plt.image(aux)
#
# AttributeError: module 'matplotlib' has no attribute 'image'

# %%
plt.figure(figsize=(15,10))
plt.imshow(aux)
plt.colorbar()
