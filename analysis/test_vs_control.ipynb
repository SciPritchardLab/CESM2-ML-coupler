# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm

# %%
#path = "/scratch/00993/tg802402/NNrealgeographyonline003/run" # v8 fit -- ice issues.
path = "/scratch/00993/tg802402/NNrealgeographyonline004-v11fit/run" # v11 fit -- 10x weight to ice (I think)
files = xr.open_mfdataset(path+"/*.cam.h2.2007-04-02-[01]*.nc")

it=9

T= files.NN_BP2BC_DT.isel(time=it).mean(dim=("lon")).values
T0= files.SP_BP2BC_DT.isel(time=it).mean(dim=("lon")).values

Q= files.NN_BP2BC_DQ.isel(time=it).mean(dim=("lon")).values
Q0= files.SP_BP2BC_DQ.isel(time=it).mean(dim=("lon")).values

QC= files.NN_BP2BC_DQC.isel(time=it).mean(dim=("lon")).values
QC0= files.SP_BP2BC_DQC.isel(time=it).mean(dim=("lon")).values

QI= files.NN_BP2BC_DQI.isel(time=it).mean(dim=("lon")).values
QI0= files.SP_BP2BC_DQI.isel(time=it).mean(dim=("lon")).values

X = QI
X0 = QI0


plt.figure(figsize=(15,10))
plt.subplot(311)
plt.imshow(X,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('Test')

plt.subplot(312)
plt.imshow(X0,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('CTRL')
#plt.clim(-0.4,0.4)
plt.subplot(313)
anomaly = X-X0
plt.imshow(anomaly,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('TEST-CTRL')
#plt.clim(-0.4,0.4)
# Out:
# Text(0.5, 1.0, 'TEST-CTRL')

# %%
# Out:
# Text(0.5, 1.0, 'TEST-CTRL')

# %%
plt.figure(figsize=(15,10))
plt.subplot(311)
plt.imshow(Q0,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('CTRL')
#plt.clim(-0.4,0.4)
plt.subplot(312)
plt.imshow(Q,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('TEST')
#plt.clim(-0.4,0.4)
plt.subplot(313)
anomaly = Q-Q0
plt.imshow(anomaly,norm=TwoSlopeNorm(0), cmap=plt.cm.seismic)
plt.colorbar()
plt.title ('TEST-CTRL')
#plt.clim(-0.4,0.4)
# Out:
# Text(0.5, 1.0, 'TEST-CTRL')
